# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
df_train = pd.read_csv('linear_train_data.csv')

# %%
df_train
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
df_train.isnull().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
df_train.corr()
# Out:
#          x        y
# x  1.00000  0.99534
# y  0.99534  1.00000

# %%
df_train.columns
# Out:
# Index(['x', 'y'], dtype='object')

# %%
plt.scatter(df_train['x'],df_train['y'])#here we can observe the good relationship between x and y columns

# %%
sns.heatmap(df_train.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
#-1 in reshape function is used when you dont know or want to explicitly tell the dimension of that axis. E.g,
#If you have an array of shape (2,4) then reshaping it with (-1, 1),
#then the array will get reshaped in such a way that the resulting array has only 1 column and this is only possible by having 8 rows, hence, (8,1).
x1=df_train.x.values.reshape(-1,1)
y1=df_train.y.values.reshape(-1,1)
print(x1,y1)
# Out:
# [[ 24.]
#  [ 50.]
#  [ 15.]
#  [ 38.]
#  [ 87.]
#  [ 36.]
#  [ 12.]
#  [ 81.]
#  [ 25.]
#  [  5.]
#  [ 16.]
#  [ 16.]
#  [ 24.]
#  [ 39.]
#  [ 54.]
#  [ 60.]
#  [ 26.]
#  [ 73.]
#  [ 29.]
#  [ 31.]
#  [ 68.]
#  [ 87.]
#  [ 58.]
#  [ 54.]
#  [ 84.]
#  [ 58.]
#  [ 49.]
#  [ 20.]
#  [ 90.]
#  [ 48.]
#  [  4.]
#  [ 25.]
#  [ 42.]
#  [  0.]
#  [ 60.]
#  [ 93.]
#  [ 39.]
#  [  7.]
#  [ 21.]
#  [ 68.]
#  [ 84.]
#  [  0.]
#  [ 58.]
#  [ 19.]
#  [ 36.]
#  [ 19.]
#  [ 59.]
#  [ 51.]
#  [ 19.]
#  [ 33.]
#  [ 85.]
#  [ 44.]
#  [  5.]
#  [ 59.]
#  [ 14.]
#  [  9.]
#  [ 75.]
#  [ 69.]
#  [ 10.]
#  [ 17.]
#  [ 58.]
#  [ 74.]
#  [ 21.]
#  [ 51.]
#  [ 19.]
#  [ 50.]
#  [ 24.]
#  [  0.]
#  [ 12.]
#  [ 75.]
#  [ 21.]
#  [ 64.]
#  [  5.]
#  [ 58.]
#  [ 32.]
#  [ 41.]
#  [  7.]
#  [  4.]
#  [  5.]
#  [ 49.]
#  [ 90.]
#  [  3.]
#  [ 11.]
#  [ 32.]
#  [ 83.]
#  [ 25.]
#  [ 83.]
#  [ 26.]
#  [ 76.]
#  [ 95.]
#  [ 53.]
#  [ 77.]
#  [ 42.]
#  [ 25.]
#  [ 54.]
#  [ 55.]
#  [  0.]
#  [ 73.]
#  [ 35.]
#  [ 86.]
# ...

# %%
df_train.dropna(axis=0,inplace=True)

# %%
df_train.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
print(x1.shape)
print(y1.shape)
# Out:
# (699, 1)
# (699, 1)

# %%
lr.fit(x1,y1)
# Out:
# LinearRegression()

# %%
y3=lr.predict(x1)
y3
# Out:
# array([[23.9084877 ],
#        [49.92555363],
#        [14.90258026],
#        [37.91767705],
#        [86.94983976],
#        [35.91636428],
#        [11.90061112],
#        [80.94590147],
#        [24.90914408],
#        [ 4.89601644],
#        [15.90323665],
#        [15.90323665],
#        [23.9084877 ],
#        [38.91833343],
#        [53.92817916],
#        [59.93211745],
#        [25.90980046],
#        [72.94065041],
#        [28.91176961],
#        [30.91308237],
#        [67.9373685 ],
#        [86.94983976],
#        [57.93080468],
#        [53.92817916],
#        [83.94787061],
#        [57.93080468],
#        [48.92489725],
#        [19.90586217],
#        [89.9518089 ],
#        [47.92424086],
#        [ 3.89536006],
#        [24.90914408],
#        [41.92030257],
#        [-0.10726546],
#        [59.93211745],
#        [92.95377805],
#        [38.91833343],
#        [ 6.89732921],
#        [20.90651855],
#        [67.9373685 ],
#        [83.94787061],
# ...

# %%
lr.score(x1,y1)
# Out:
# 0.9907015319025518

# %%
df_test=pd.read_csv("linear_test_data.csv")

# %%
df_test
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
x2=df_test.x.values.reshape(-1,1)
y2=df_test.y.values.reshape(-1,1)

# %%
x2,y2
# Out:
# (array([[ 77],
#         [ 21],
#         [ 22],
#         [ 20],
#         [ 36],
#         [ 15],
#         [ 62],
#         [ 95],
#         [ 20],
#         [  5],
#         [  4],
#         [ 19],
#         [ 96],
#         [ 62],
#         [ 36],
#         [ 15],
#         [ 65],
#         [ 14],
#         [ 87],
#         [ 69],
#         [ 89],
#         [ 51],
#         [ 89],
#         [ 27],
#         [ 97],
#         [ 58],
#         [ 79],
#         [ 21],
#         [ 93],
#         [ 27],
#         [ 99],
#         [ 31],
#         [ 33],
#         [ 80],
#         [ 28],
#         [ 47],
#         [ 53],
#         [ 69],
#         [ 28],
#         [ 33],
#         [ 91],
#         [ 71],
#         [ 50],
#         [ 76],
#         [  4],
#         [ 37],
#         [ 70],
#         [ 68],
#         [ 40],
#         [ 35],
#         [ 94],
#         [ 88],
#         [ 52],
#         [ 31],
#         [ 59],
#         [  0],
#         [ 39],
#         [ 64],
# ...

# %%
y3=lr.predict(x2)

# %%
y3
# Out:
# array([[76.94327594],
#        [20.90651855],
#        [21.90717494],
#        [19.90586217],
#        [35.91636428],
#        [14.90258026],
#        [61.93343021],
#        [94.95509081],
#        [19.90586217],
#        [ 4.89601644],
#        [ 3.89536006],
#        [18.90520579],
#        [95.95574719],
#        [61.93343021],
#        [35.91636428],
#        [14.90258026],
#        [64.93539936],
#        [13.90192388],
#        [86.94983976],
#        [68.93802488],
#        [88.95115252],
#        [50.92621001],
#        [88.95115252],
#        [26.91045685],
#        [96.95640358],
#        [57.93080468],
#        [78.9445887 ],
#        [20.90651855],
#        [92.95377805],
#        [26.91045685],
#        [98.95771634],
#        [30.91308237],
#        [32.91439514],
#        [79.94524508],
#        [27.91111323],
#        [46.92358448],
#        [52.92752277],
#        [68.93802488],
#        [27.91111323],
#        [32.91439514],
#        [90.95246528],
# ...

# %%
plt.scatter(x2,y2)
plt.plot(x2,y3,c='r')

# %%
# Here we can observe good linear relationship between the x2 and y3
